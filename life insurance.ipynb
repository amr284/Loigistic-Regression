# %% [markdown]
# # buy life insurnace

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %% [markdown]
# ![%D9%85%D8%A7-%D9%87%D9%88-%D9%85%D8%B9%D9%86%D9%89-%D9%88-%D8%AA%D8%B9%D8%B1%D9%8A%D9%81-%D8%A7%D9%84%D8%AA%D8%A3%D9%85%D9%8A%D9%86-%D8%B9%D9%84%D9%89-%D8%A7%D9%84%D8%AD%D9%8A%D8%A7%D8%A9.jpg](attachment:%D9%85%D8%A7-%D9%87%D9%88-%D9%85%D8%B9%D9%86%D9%89-%D9%88-%D8%AA%D8%B9%D8%B1%D9%8A%D9%81-%D8%A7%D9%84%D8%AA%D8%A3%D9%85%D9%8A%D9%86-%D8%B9%D9%84%D9%89-%D8%A7%D9%84%D8%AD%D9%8A%D8%A7%D8%A9.jpg)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("life insurance.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance , marker="+" , color = "red" )

# %% [markdown]
# use trained split method to split our data set

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df[["age"]] ,df.bought_insurance ,test_size=0.1 )

# %%
X_test
# Out:
#     age
# 26   23
# 3    52
# 0    22

# %%
X_train
# Out:
#     age
# 21   26
# 24   50
# 6    55
# 11   28
# 1    25
# 19   18
# 15   55
# 5    56
# 13   29
# 14   49
# 17   58
# 18   19
# 25   54
# 10   18
# 4    46
# 7    60
# 8    62
# 20   21
# 12   27
# 2    47
# 23   45
# 22   40
# 16   25
# 9    61

# %%
y_train
# Out:
# 21    0
# 24    1
# 6     0
# 11    0
# 1     0
# 19    0
# 15    1
# 5     1
# 13    0
# 14    1
# 17    1
# 18    0
# 25    1
# 10    0
# 4     1
# 7     1
# 8     1
# 20    0
# 12    0
# 2     1
# 23    1
# 22    1
# 16    1
# 9     1
# Name: bought_insurance, dtype: int64

# %%
# import logistic regression model
from sklearn.linear_model import LogisticRegression

# %%
# create object of this class w for call it model 
model = LogisticRegression()

# %%
# training the model
model.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
# means our model is perfect
model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
# predict probability of x test
model.predict_proba(X_test)
# Out:
# array([[0.88616317, 0.11383683],
#        [0.07677115, 0.92322885],
#        [0.90102436, 0.09897564]])

# %%
model.predict([[56]])
# Out:
# C:\Users\Amr mohamed\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model.predict([[2]])
# Out:
# C:\Users\Amr mohamed\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
